# %%
from classifier import *
from preprocessing import *
from staff_line_removal import *

# %%
# preprocess the image
img = cv2.imread('sample.png', 0)
binarized = 255 - binarize(img, 'cv_adaptive')
io.imsave('binarized.png', binarized)
cleaned = staff_removal(img)
segmented, symbols = segmentation(cleaned)
# Out:
# contours detected: 86

# %%
print('Loading dataset. This will take time ...')
features, labels = load_dataset('hog')
print('Finished loading dataset.')

train_features, test_features, train_labels, test_labels = train_test_split(
    features, labels, test_size=0.2, random_state=random_seed)
# Out:
# Loading dataset. This will take time ...
# finished processing:  a_1
# finished processing:  a_16
# finished processing:  a_16_flipped
# finished processing:  a_1_flipped
# finished processing:  a_2
# finished processing:  a_2_flipped
# finished processing:  a_32
# finished processing:  a_32_flipped
# finished processing:  a_4
# finished processing:  a_4_flipped
# finished processing:  a_8
# finished processing:  a_8_flipped
# finished processing:  barline
# finished processing:  b_16
# finished processing:  b_8
# finished processing:  c
# finished processing:  d
# finished processing:  dot
# finished processing:  e
# finished processing:  f
# finished processing:  t_4_4
# finished processing:  z
# Finished loading dataset.

# %%
svm = classifiers['SVM']
svm.fit(train_features, train_labels)
accuracy = svm.score(test_features, test_labels)
print('SVM ', 'accuracy:', accuracy*100, '%')
# Out:
# SVM  accuracy: 98.31387808041504 %

# %%
img = cv2.imread('lol.png', 0)
# binarized = binarize(img, 'cv_adaptive')
feature = extract_features(img, 'hog')
print(feature)
print(svm.predict([feature]))
io.imshow(img)
io.show()
# Out:
# [0.         0.         0.         ... 0.         0.         0.09540179]
# ['a_4']

# %%
for symbol in symbols:
    feature = extract_features(symbol, 'hog')
    print(feature)
    print(svm.predict([feature]))
    io.imshow(symbol)
    io.show()
# Out:
# [0.0011457  0.00756665 0.02010599 ... 0.         0.         0.        ]
# ['a_1']
# [0.         0.         0.         ... 0.         0.         0.07478909]
# ['dot']
# [0.08264183 0.17960967 0.2745398  ... 0.         0.         0.        ]
# ['dot']
# [0.30635983 0.20185469 0.06582724 ... 0.         0.         0.        ]
# ['z']
# [0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 2.3898651e-04 7.9865298e-05
#  0.0000000e+00]
# ['a_2']
# [0.         0.         0.         ... 0.         0.         0.00216432]
# ['a_2']
# [0.04351107 0.1624415  0.2724108  ... 0.         0.         0.        ]
# ['dot']
# [0. 0. 0. ... 0. 0. 0.]
# ['a_2']
# [0.         0.         0.         ... 0.00112879 0.00414328 0.00085853]
# ['a_2']
# [0.         0.         0.         ... 0.0037292  0.00124624 0.        ]
# ['a_2']
# [0.         0.         0.         ... 0.01027709 0.         0.        ]
# ['a_2']
# [0.19808313 0.04211614 0.         ... 0.01176143 0.00393047 0.37349662]
# ['barline']
# [0.00478617 0.00519865 0.01765154 ... 0.28609845 0.28609845 0.06598976]
# ['a_2_flipped']
# [0.         0.         0.         ... 0.00183972 0.0006148  0.00107217]
# ['a_2']
# [0.         0.         0.         ... 0.         0.         0.00057265]
# ['a_2']
# [0.         0.         0.         ... 0.         0.         0.00391273]
# ['a_2']
# [0. 0. 0. ... 0. 0. 0.]
# ['a_2']
# [0.17160478 0.02793215 0.01088125 ... 0.         0.         0.13071227]
# ['barline']
# [0. 0. 0. ... 0. 0. 0.]
# ['a_2']
# [0. 0. 0. ... 0. 0. 0.]
# ['a_2']
# [0.         0.         0.         ... 0.03399298 0.0057366  0.00106561]
# ['f']
# [0.02595831 0.05217848 0.05196625 ... 0.2771479  0.19392155 0.11998241]
# ['a_32']
# [0.01170791 0.00890981 0.04815897 ... 0.         0.         0.00702047]
# ['a_1']
# [0.00520327 0.01359732 0.03240576 ... 0.         0.         0.        ]
# ['z']
# [0.01905466 0.14039855 0.30637783 ... 0.         0.         0.        ]
# ['dot']
# [3.6790667e-03 2.4280410e-04 7.2655961e-04 ... 2.9676828e-01 2.8868577e-01
#  6.7860939e-02]
# ['z']
# [0.02631912 0.14741999 0.27708435 ... 0.         0.         0.        ]
# ['dot']
# [0. 0. 0. ... 0. 0. 0.]
# ['a_2']
# [0.         0.         0.         ... 0.         0.         0.00350496]
# ['a_2']
# [0.05728857 0.17730296 0.28324345 ... 0.         0.         0.        ]
# ['dot']
# [0. 0. 0. ... 0. 0. 0.]
# ['a_2']
# [0. 0. 0. ... 0. 0. 0.]
# ['a_2']
# [0.11757515 0.00504268 0.0663925  ... 0.         0.01198595 0.04514823]
# ['a_1_flipped']
# [0. 0. 0. ... 0. 0. 0.]
# ['a_2']
# [0.         0.         0.         ... 0.00349594 0.00116829 0.01117233]
# ['a_2']
# [0.         0.         0.         ... 0.00402327 0.00134451 0.00460819]
# ['a_2']
# [0.         0.         0.         ... 0.00276072 0.00345071 0.00346363]
# ['a_2']
# [0.         0.         0.         ... 0.13564387 0.09400813 0.1764671 ]
# ['z']
# [0.13910174 0.05652811 0.02243557 ... 0.         0.         0.1707848 ]
# ['barline']
# [0.         0.         0.         ... 0.00944054 0.01978635 0.04366588]
# ['a_2']
# [0.         0.         0.         ... 0.03473738 0.02082307 0.00267444]
# ['f']
# [0.23929968 0.00087482 0.         ... 0.         0.         0.        ]
# ['barline']
# [0.         0.         0.         ... 0.00065548 0.         0.        ]
# ['a_32']
# [0.00567984 0.00280212 0.         ... 0.17572106 0.10298146 0.0574129 ]
# ['z']
# [0.05868517 0.14846718 0.28267244 ... 0.         0.         0.        ]
# ['barline']
# [0.         0.         0.         ... 0.05277018 0.01679674 0.00026085]
# ['a_2']
# [0.21587592 0.16121246 0.01657551 ... 0.         0.         0.37006435]
# ['barline']
# [0.         0.         0.         ... 0.         0.         0.01729886]
# ['a_2']
# [0. 0. 0. ... 0. 0. 0.]
# ['a_2']
# [0. 0. 0. ... 0. 0. 0.]
# ['a_2']
# [0.1117304  0.26971084 0.14522839 ... 0.         0.         0.04175759]
# ['a_1_flipped']
# [0.         0.         0.         ... 0.00592999 0.02121684 0.04674109]
# ['a_2']
# [0.         0.         0.         ... 0.00298222 0.01563999 0.05970195]
# ['a_2']
# [0.         0.         0.         ... 0.01267147 0.0253345  0.02184496]
# ['a_2']
# [0.         0.         0.         ... 0.         0.01837135 0.0665621 ]
# ['a_2']
# [0.         0.         0.         ... 0.00410681 0.00993857 0.04764634]
# ['a_2']
# [0.23150606 0.00404442 0.         ... 0.         0.         0.3212455 ]
# ['a_1_flipped']
# [0.2207154  0.00493978 0.         ... 0.01776487 0.00593672 0.29602224]
# ['a_1_flipped']
# [0.0047377  0.00024319 0.00072771 ... 0.18461768 0.19086252 0.14847897]
# ['z']
# [0.        0.        0.        ... 0.        0.        0.0012881]
# ['a_2']
# [0.         0.         0.         ... 0.         0.         0.00199634]
# ['a_2']
# [0. 0. 0. ... 0. 0. 0.]
# ['a_2']
# [0.16685337 0.04434956 0.         ... 0.         0.         0.18192993]
# ['barline']
# [0.         0.         0.         ... 0.         0.         0.00818775]
# ['a_2_flipped']
# [0.08481421 0.0123148  0.03685057 ... 0.         0.         0.        ]
# ['dot']
# C:\Users\abdal\anaconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:150: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)
# [0.1817599  0.10665199 0.02641278 ... 0.         0.         0.33107135]
# ['dot']
# [0.01035591 0.05314626 0.07511901 ... 0.         0.         0.00211688]
# ['a_1']
# [0.05938521 0.13919474 0.25720623 ... 0.         0.         0.        ]
# ['z']
# [0. 0. 0. ... 0. 0. 0.]
# ['a_32']
# [0.00425531 0.00186879 0.         ... 0.14345935 0.1928743  0.21155073]
# ['z']
# [0.0533663  0.15741457 0.29073486 ... 0.         0.         0.04640699]
# ['dot']
# [0. 0. 0. ... 0. 0. 0.]
# ['a_2']
# [0.         0.         0.         ... 0.         0.         0.00778128]
# ['a_2']
# [0.3226896  0.00436351 0.         ... 0.         0.         0.04661232]
# ['a_1_flipped']
# [0.05635329 0.0667761  0.18642385 ... 0.         0.         0.10253035]
# ['a_1_flipped']
# [0.         0.         0.         ... 0.         0.         0.00746876]
# ['a_2']
# [0.         0.         0.         ... 0.         0.         0.03735603]
# ['a_2']
# [0.         0.         0.         ... 0.         0.         0.00291377]
# ['a_2']
# [0.         0.         0.         ... 0.         0.         0.00111176]
# ['a_2']
# [0.         0.         0.         ... 0.         0.         0.02128902]
# ['a_2']
# [0.         0.         0.         ... 0.         0.         0.05712669]
# ['a_2']
# [0.00563684 0.0027809  0.         ... 0.32485715 0.32485715 0.03612475]
# ['z']
# [0.13912785 0.08427833 0.04912599 ... 0.00124593 0.00792833 0.34995615]
# ['z']
# [0.17703633 0.0145026  0.04509975 ... 0.         0.         0.10541303]
# ['barline']
# [0. 0. 0. ... 0. 0. 0.]
# ['a_2']
# [0.         0.         0.00175229 ... 0.         0.         0.00829531]
# ['z']
